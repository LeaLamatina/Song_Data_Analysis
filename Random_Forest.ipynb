# %%
from sklearn import tree
import pandas as pd
import os
from sklearn import preprocessing

# %%
df = pd.read_csv(os.path.join("Resources", "Spotify_Audio_Features.csv"))
df.head()
# Out:
#    Unnamed: 0    artist_name                          track_name  \
# 0           0  Ariana Grande                       thank u, next
# 1           1   Los Unidades                  E-Lo (feat. Jozzy)
# 2           2   Travis Scott                          SICKO MODE
# 3           3      Sheck Wes                            Mo Bamba
# 4           4    Kodak Black  ZEZE (feat. Travis Scott & Offset)
#
#                  track_id  popularity  acousticness  danceability  \
# 0  2rPE9A1vEgShuZxxzR2tZH         100       0.28000         0.724
# 1  3eydp9rHJAskzOevEBK267          69       0.46900         0.698
# 2  2xLMifQCjDGFmkHkpNLD9h          94       0.00513         0.834
# 3  1xzBco0xcoJEDXktl7Jxrr          93       0.19400         0.729
# 4  7l3E7lcozEodtVsSTCkcaA          94       0.05150         0.861
#
#    duration_ms  energy  instrumentalness     key  liveness  loudness   mode  \
# 0       207333   0.647          0.000000  C♯, D♭    0.1020    -5.642  Minor
# 1       214720   0.797          0.001180  D♯, E♭    0.1520    -5.125  Major
# 2       312820   0.730          0.000000  G♯, A♭    0.1240    -3.714  Minor
# 3       183907   0.625          0.009860       E    0.2480    -5.266  Minor
# 4       228654   0.637          0.000003  G♯, A♭    0.0967    -5.692  Major
#
#    speechiness    tempo  time_signature  valence
# 0       0.0658  106.960               4    0.435
# 1       0.0615  101.969               4    0.530
# 2       0.2220  155.008               4    0.446
# 3       0.0315  146.034               4    0.261
# 4       0.2400   98.044               4    0.474

# %%
bins = [-1, 24, 249, 10000]

labels = ["hot", "popular", "random"]

# %%
df["Hit Songs"] = pd.cut(df["Unnamed: 0"], bins, labels=labels)
df.head()
# Out:
#    Unnamed: 0    artist_name                          track_name  \
# 0           0  Ariana Grande                       thank u, next
# 1           1   Los Unidades                  E-Lo (feat. Jozzy)
# 2           2   Travis Scott                          SICKO MODE
# 3           3      Sheck Wes                            Mo Bamba
# 4           4    Kodak Black  ZEZE (feat. Travis Scott & Offset)
#
#                  track_id  popularity  acousticness  danceability  \
# 0  2rPE9A1vEgShuZxxzR2tZH         100       0.28000         0.724
# 1  3eydp9rHJAskzOevEBK267          69       0.46900         0.698
# 2  2xLMifQCjDGFmkHkpNLD9h          94       0.00513         0.834
# 3  1xzBco0xcoJEDXktl7Jxrr          93       0.19400         0.729
# 4  7l3E7lcozEodtVsSTCkcaA          94       0.05150         0.861
#
#    duration_ms  energy  instrumentalness     key  liveness  loudness   mode  \
# 0       207333   0.647          0.000000  C♯, D♭    0.1020    -5.642  Minor
# 1       214720   0.797          0.001180  D♯, E♭    0.1520    -5.125  Major
# 2       312820   0.730          0.000000  G♯, A♭    0.1240    -3.714  Minor
# 3       183907   0.625          0.009860       E    0.2480    -5.266  Minor
# 4       228654   0.637          0.000003  G♯, A♭    0.0967    -5.692  Major
#
#    speechiness    tempo  time_signature  valence Hit Songs
# 0       0.0658  106.960               4    0.435       hot
# 1       0.0615  101.969               4    0.530       hot
# 2       0.2220  155.008               4    0.446       hot
# 3       0.0315  146.034               4    0.261       hot
# 4       0.2400   98.044               4    0.474       hot

# %%
drop_list = ['track_name', 'track_id', 'Unnamed: 0']
data = df.drop(drop_list, axis=1)
data.head()
# Out:
#      artist_name  popularity  acousticness  danceability  duration_ms  energy  \
# 0  Ariana Grande         100       0.28000         0.724       207333   0.647
# 1   Los Unidades          69       0.46900         0.698       214720   0.797
# 2   Travis Scott          94       0.00513         0.834       312820   0.730
# 3      Sheck Wes          93       0.19400         0.729       183907   0.625
# 4    Kodak Black          94       0.05150         0.861       228654   0.637
#
#    instrumentalness     key  liveness  loudness   mode  speechiness    tempo  \
# 0          0.000000  C♯, D♭    0.1020    -5.642  Minor       0.0658  106.960
# 1          0.001180  D♯, E♭    0.1520    -5.125  Major       0.0615  101.969
# 2          0.000000  G♯, A♭    0.1240    -3.714  Minor       0.2220  155.008
# 3          0.009860       E    0.2480    -5.266  Minor       0.0315  146.034
# 4          0.000003  G♯, A♭    0.0967    -5.692  Major       0.2400   98.044
#
#    time_signature  valence Hit Songs
# 0               4    0.435       hot
# 1               4    0.530       hot
# 2               4    0.446       hot
# 3               4    0.261       hot
# 4               4    0.474       hot

# %%
#Encode track id, track name and artistname into quantitative
le = preprocessing.LabelEncoder()
data['Hit Songs'] = le.fit_transform(data['Hit Songs'].astype('str'))
data['key'] = le.fit_transform(data['key'].astype('str'))
data['artist_name'] = le.fit_transform(data['artist_name'].astype('str'))
data['mode'] = le.fit_transform(data['mode'].astype('str'))

# %%
target = data["Hit Songs"]
target_names = ["negative", "positive"]

# %%
train = data.drop("Hit Songs", axis=1)
feature_names = data.columns
train.head()
# Out:
#    artist_name  popularity  acousticness  danceability  duration_ms  energy  \
# 0          117         100       0.28000         0.724       207333   0.647
# 1         1047          69       0.46900         0.698       214720   0.797
# 2         1750          94       0.00513         0.834       312820   0.730
# 3         1530          93       0.19400         0.729       183907   0.625
# 4          948          94       0.05150         0.861       228654   0.637
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000    4    0.1020    -5.642     1       0.0658  106.960
# 1          0.001180    6    0.1520    -5.125     0       0.0615  101.969
# 2          0.000000   11    0.1240    -3.714     1       0.2220  155.008
# 3          0.009860    7    0.2480    -5.266     1       0.0315  146.034
# 4          0.000003   11    0.0967    -5.692     0       0.2400   98.044
#
#    time_signature  valence
# 0               4    0.435
# 1               4    0.530
# 2               4    0.446
# 3               4    0.261
# 4               4    0.474

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9433551198257081

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.9607843137254902

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.38377381020669704, 'popularity'),
#  (0.06742507841687495, 'artist_name'),
#  (0.06541806667793179, 'loudness'),
#  (0.057599427751703444, 'speechiness'),
#  (0.054883349341187444, 'danceability'),
#  (0.0543647256717665, 'liveness'),
#  (0.05328538882265699, 'duration_ms'),
#  (0.05305993861822636, 'tempo'),
#  (0.04977115437652271, 'valence'),
#  (0.04781915785824598, 'energy'),
#  (0.04781005227987649, 'acousticness'),
#  (0.026456787277168138, 'instrumentalness'),
#  (0.02549296923825632, 'key'),
#  (0.008845595558104552, 'mode'),
#  (0.003994497904781281, 'time_signature')]
